# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %% [markdown]
# # Logistic Regression Model - 30 Second Tabular Data

# %%
# Importing data
df_30_sec = pd.read_csv("../data/features_30_sec.csv")
# Adding a C parameter for regularization (model is overfitting on train data)
clf = LogisticRegression(max_iter=1000, C=0.1)

## Encoding the Labels 0 - 9
le = LabelEncoder()
df_30_sec['label_encoded'] = le.fit_transform(df_30_sec['label'])

y = df_30_sec["label_encoded"].to_numpy()
X = df_30_sec.drop(columns=["filename", "length", "label", "label_encoded"]).to_numpy()

## Train / Test split
[X_train, X_test, y_train, y_test] = train_test_split(X, y, test_size = .3, random_state=42)

# Scaling Data 
clf = make_pipeline(StandardScaler(), LogisticRegression(max_iter=1000))

# Fitting logistic regression and evaluating
clf.fit(X_train, y_train)
train_acc = clf.score(X_train,y_train)
test_acc = clf.score(X_test, y_test)
prediction = clf.predict(X_test)

print("train acc:", train_acc)
print("test acc:", test_acc)

print(classification_report(y_test, prediction))
# Out:
# train acc: 0.9128571428571428
# test acc: 0.6933333333333334
#               precision    recall  f1-score   support
#
#            0       0.62      0.71      0.67        35
#            1       0.95      1.00      0.98        20
#            2       0.62      0.65      0.63        37
#            3       0.75      0.71      0.73        34
#            4       0.55      0.67      0.60        24
#            5       0.96      0.76      0.85        33
#            6       0.72      0.87      0.79        30
#            7       0.76      0.70      0.73        23
#            8       0.56      0.52      0.54        29
#            9       0.59      0.49      0.53        35
#
#     accuracy                           0.69       300
#    macro avg       0.71      0.71      0.70       300
# weighted avg       0.70      0.69      0.69       300
